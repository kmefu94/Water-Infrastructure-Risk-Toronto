# %%
import sys
import pandas as pd
from pathlib import Path
pd.set_option('display.max_columns', None)
sys.path.append(str(Path.cwd().parent / "src"))
import csv
import numpy
import utils.data_loader as dl
import utils.data_summaries as ds
import utils.standardize_columns as sc

# %%
print(dir(dl))
print(dir(ds))
print(dir(sc))
# Out:
# ['Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'csv', 'get_sources', 'pd', 'pull_data', 'read_files']
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'check_duplicates', 'column_presence', 'compare_columns', 'full_summary', 'pd', 'quick_summary', 'search_df']
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_resolve', 'col_to_bool', 'col_to_cat', 'col_to_date', 'col_to_float', 'col_to_int', 'col_to_snake', 'col_to_str', 'pd', 're']

# %%
#Read available datasets available for data source
path = "C:\\Users\\1\\Desktop\\project\\data\\cleaned_data"
DataSources = dl.get_sources(path)
print(DataSources)
# Out:
# [WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/311'), WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/climate'), WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/neighbourhoods'), WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/ward_census'), WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/watermain_breaks'), WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/watermains'), WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/weather')]

# %%
source = DataSources[2]
readable = dl.read_files(source)
readable
# Out:
# CSV
#   neighbourhoods_clean.csv
# [WindowsPath('C:/Users/1/Desktop/project/data/cleaned_data/neighbourhoods/neighbourhoods_clean.csv')]

# %%
data = dl.pull_data(source)
print(f"number of datasets from source: {len(data)}")
print(f"names of remaining datasets: {data.keys()}")
# Out:
# CSV
#   neighbourhoods_clean.csv
# number of datasets from source: 1
# names of remaining datasets: dict_keys(['neighbourhoods_clean'])

# %%
hoods = data['neighbourhoods_clean']
print(ds.quick_summary(hoods))
hoods = hoods.drop(columns = ["id","parent_area_id","classification_code"]).reset_index(drop=True) #drop id, parent_area_id, and classfication_code
# Out:
#                        dtype  col_index  missing_pct  n_unique
# id                     int64          0     0.000000       158
# area_id                int64          1     0.000000       158
# area_attr_id           int64          2     0.000000       158
# parent_area_id       float64          3     1.000000         0
# area_short_code        int64          4     0.000000       158
# area_long_code         int64          5     0.000000       158
# area_name             object          6     0.000000       158
# area_desc             object          7     0.000000       158
# classification        object          8     0.000000         3
# classification_code   object          9     0.727848         2
# objectid               int64         10     0.000000       158
#      area_id  area_attr_id  area_short_code  area_long_code  \
# 0    2502366      26022881              174             174
# 1    2502365      26022880              173             173
# 2    2502364      26022879              172             172
# 3    2502363      26022878              171             171
# 4    2502362      26022877              170             170
# ..       ...           ...              ...             ...
# 153  2502213      26022728                1               1
# 154  2502212      26022727               24              24
# 155  2502211      26022726               23              23
# 156  2502210      26022725               22              22
# 157  2502209      26022724               21              21
#
#                      area_name                        area_desc  \
# 0    South Eglinton-Davisville  South Eglinton-Davisville (174)
# 1                North Toronto              North Toronto (173)
# 2           Dovercourt Village         Dovercourt Village (172)
# 3     Junction-Wallace Emerson   Junction-Wallace Emerson (171)
# 4           Yonge-Bay Corridor         Yonge-Bay Corridor (170)
# ..                         ...                              ...
# 153     West Humber-Clairville       West Humber-Clairville (1)
# 154                Black Creek                 Black Creek (24)
# 155       Pelmo Park-Humberlea        Pelmo Park-Humberlea (23)
# 156                 Humbermede                  Humbermede (22)
# 157              Humber Summit               Humber Summit (21)
#
#                            classification  objectid
# 0    Not an NIA or Emerging Neighbourhood  17824737
# 1    Not an NIA or Emerging Neighbourhood  17824753
# 2    Not an NIA or Emerging Neighbourhood  17824769
# 3    Not an NIA or Emerging Neighbourhood  17824785
# 4    Not an NIA or Emerging Neighbourhood  17824801
# ..                                    ...       ...
# 153  Not an NIA or Emerging Neighbourhood  17827185
# 154        Neighbourhood Improvement Area  17827201
# 155  Not an NIA or Emerging Neighbourhood  17827217
# 156        Neighbourhood Improvement Area  17827233
# 157        Neighbourhood Improvement Area  17827249
#
# [158 rows x 8 columns]

# %%
hoods['classification'].value_counts()
# Out:
# classification
# Not an NIA or Emerging Neighbourhood    115
# Neighbourhood Improvement Area           33
# Emerging Neighbourhood                   10
# Name: count, dtype: int64
